# %% [markdown]
# ## Correlation of gauge pair P by separation distance (m)
# # DON'T USE THIS - IT'S NOT NEEDED!!!!!

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn' this removes the warning when renaming columns
import math
from scipy import stats
import scipy
# import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read in monthly corr table csv files

# %%
# Oct
distcorroct_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corroct_table_2005-16.csv", 
                            header=0)
# rename columns
distcorroct_df.rename(columns={'corr_coeff':'oct_corr','separation_distance_m': 'dist_m'}, inplace=True)
# set column positions
distcorroct_df = distcorr_oct_df[['station_pair', 'dist_m', 'oct_corr']]
distcorroct_df
# Out:
#    station_pair  dist_m  oct_corr
# 0          FRUC    2020     0.966
# 1          UCHM    2910     0.894
# 2          FRHM    4770     0.841
# 3         UCBCS   45830     0.645
# 4         FRBCS   44750     0.637
# 5           KWH   34730     0.626
# 6         HMBCS   48450     0.621
# 7           HMK   36890     0.526
# 8          KBCS   46750     0.506
# 9           UCK   12650     0.472
# 10          FRK   14310     0.437
# 11         FRKP   27730     0.387
# 12        BCSWH   58090     0.375
# 13         UCKP   27420     0.367
# 14        KPBCS   71390     0.363
# 15          KBV    6600     0.362
# 16         HMBV   16300     0.354
# 17         UCBV   16040     0.329
# 18        BVBCS   41210     0.327
# 19         FRWH   48580     0.314
# 20         UCWH   47160     0.305
# 21         HMWH   46540     0.297
# 22          KKP   35550     0.296
# 23         FRBV   17140     0.292
# 24         KPWH   67980     0.219
# 25         HMKP   25800     0.204
# ...

# %%
# Nov
distcorrnov_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrnov_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrnov_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrnov_df.rename(columns={'corr_coeff':'nov_corr'}, inplace=True)
# distcorrnov_df

# %%
# Dec
distcorrdec_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrdec_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrdec_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrdec_df.rename(columns={'corr_coeff':'dec_corr'}, inplace=True)
# distcorrdec_df

# %%
# Jan
distcorrjan_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrjan_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrjan_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrjan_df.rename(columns={'corr_coeff':'jan_corr'}, inplace=True)
# distcorrjan_df

# %%
# Feb
distcorrfeb_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrfeb_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrfeb_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrfeb_df.rename(columns={'corr_coeff':'feb_corr'}, inplace=True)
# distcorrfeb_df

# %%
# Mar
distcorrmar_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrmar_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrmar_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrmar_df.rename(columns={'corr_coeff':'mar_corr'}, inplace=True)
# distcorrmar_df

# %%
# Apr
distcorrapr_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrapr_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrapr_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrapr_df.rename(columns={'corr_coeff':'apr_corr'}, inplace=True)
# distcorrapr_df

# %%
# May
distcorrmay_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrmay_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrmay_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrmay_df.rename(columns={'corr_coeff':'may_corr'}, inplace=True)
# distcorrmay_df

# %%
# Jun
distcorrjun_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrjun_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrjun_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrjun_df.rename(columns={'corr_coeff':'jun_corr'}, inplace=True)
# distcorrjun_df

# %%
# Jul
distcorrjul_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrjul_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrjul_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrjul_df.rename(columns={'corr_coeff':'jul_corr'}, inplace=True)
# distcorrjul_df

# %%
# Aug
distcorraug_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corraug_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorraug_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorraug_df.rename(columns={'corr_coeff':'aug_corr'}, inplace=True)
# distcorraug_df

# %%
# Sep
distcorrsep_df = pd.read_csv(r"C:\Users\b1043453\OneDrive - Newcastle University\OnePlanet PhD\Random_mixing\RMWSPy_Horning_and_Haese_2021\RMWSPy-master\MCRB_examples\MCRB_gauges_only\Characterising_P_statistics\correlation_plots_2005-2016_stns\monthly_plots\corrsep_table_2005-16.csv", 
                            header=0)
# drop unwamted columns
distcorrsep_df.drop(['station_pair', 'separation_distance_m'], axis=1, inplace=True)
# rename columns
distcorrsep_df.rename(columns={'corr_coeff':'sep_corr'}, inplace=True)
# distcorrsep_df

# %% [markdown]
# ### Concatenate

# %%
distcorr_df = pd.concat([distcorroct_df, distcorrnov_df, distcorrdec_df, distcorrjan_df,
                         distcorrfeb_df, distcorrmar_df, distcorrapr_df, distcorrmay_df,
                         distcorrjun_df, distcorrjul_df, distcorraug_df, distcorrsep_df], axis=1, join="outer")
distcorr_df
# Out:
#    station_pair  dist_m  oct_corr  nov_corr  dec_corr  jan_corr  feb_corr  \
# 0          FRUC    2020     0.966     0.939     0.945     0.931     0.933
# 1          UCHM    2910     0.894     0.888     0.894     0.929     0.908
# 2          FRHM    4770     0.841     0.821     0.822     0.846     0.877
# 3         UCBCS   45830     0.645     0.804     0.807     0.781     0.722
# 4         FRBCS   44750     0.637     0.766     0.771     0.763     0.718
# 5           KWH   34730     0.626     0.750     0.732     0.739     0.671
# 6         HMBCS   48450     0.621     0.741     0.715     0.691     0.640
# 7           HMK   36890     0.526     0.716     0.705     0.600     0.591
# 8          KBCS   46750     0.506     0.705     0.704     0.585     0.575
# 9           UCK   12650     0.472     0.657     0.698     0.573     0.575
# 10          FRK   14310     0.437     0.655     0.698     0.528     0.572
# 11         FRKP   27730     0.387     0.652     0.626     0.488     0.560
# ...

# %%
fig, ax = plt.subplots(figsize=(15,7), facecolor="white")

plt.plot(distcorr_df.dist_m, distcorr_df.oct_corr, color="black")


# plt.text(2485, -8.8, 'Jan: slope = -0.00255, r2 = 0.806)', fontsize="14", color="black")
# plt.plot(X, Yfeb_pred, color="maroon")
# plt.text(2485, -9.8, 'Feb: slope = -0.00357, r2 = 0.907)', fontsize="14", color="maroon")
# plt.plot(X, Ymar_pred, color="red")
# plt.text(2485, -7.0, 'Mar: slope = -0.00531, r2 = 0.967', fontsize="14", color="red")
# plt.plot(X, Yapr_pred, color="brown")
# plt.text(2485, -4.0, 'Apr: slope = -0.00583, r2 = 0.970)', fontsize="14", color="brown")
# plt.plot(X, Ymay_pred, color="darkgoldenrod")
# plt.text(2485, 1.1, "May: slope = -0.00545, r2 = 0.969)", fontsize="14", color="darkgoldenrod")
# plt.plot(X, Yjun_pred, color="green")
# plt.text(2485, 6.0, "Jun: slope = -0.00549, r2 = 0.981)", fontsize="14", color="green")
# plt.plot(X, Yjul_pred, color="darkcyan")
# plt.text(2485, 10.0, "Jul: slope = -0.00460, r2 = 0.973)", fontsize="14", color="darkcyan")
# plt.plot(X, Yaug_pred, color="grey")
# plt.text(2485, 9.0, "Aug: slope = -0.00397, r2 = 0.953)", fontsize="14", color="grey")
# plt.plot(X, Ysep_pred, color="blue")
# plt.text(2485, 4.8, "Sep: slope = -0.00386, r2 = 0.938)", fontsize="14", color="blue")
# plt.plot(X, Yoct_pred, color="indigo")
# plt.text(2485, -1.2, "Oct: slope = -0.00469, r2 = 0.948)", fontsize="14", color="indigo")
# plt.plot(X, Ynov_pred, color="mediumorchid")
# plt.text(2485, -7.9, "Nov: slope = -0.00416, r2 = 0.935)", fontsize="14", color="mediumorchid")
# plt.plot(X, Ydec_pred, color="deeppink")
# plt.text(2485, -10.7, "Dec: slope = -0.00267, r2 = 0.828)", fontsize="14", color="deeppink")

# %%
distcorr_df.plot()
# Out:
# <AxesSubplot:>
